# %%
library(dbplyr)
library(dplyr)
library(odbc)
library(plutoR)
options("scipen"=999)
source("config.R")
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:dbplyr’:
#
#     ident, sql
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# ### get all NSE indices for the latest time_stamp

# %%
indices<-Indices()

# %%
maxDt <- (indices$NseTimeSeries() %>% summarize(MAX_TS = max(TIME_STAMP)) %>% collect())$MAX_TS[1]
indices$NseTimeSeries() %>%
     group_by(NAME) %>%
     filter(TIME_STAMP == maxDt) %>%
     select(NAME) %>%
     print(n = Inf)
# Out:
# Warning message:
# “Missing values are always removed in SQL.
# Use `MAX(x, na.rm = TRUE)` to silence this warning
# This warning is displayed only once per session.”
# # Source:   lazy query [?? x 1]
# # Database: Microsoft SQL Server 13.00.4224[ro1@NORWAY/StockViz]
# # Groups:   NAME
#     NAME
#     <chr>
#   1 NIFTY 100
#   2 NIFTY 100 TR
#   3 Nifty 1D Rate Index
#   4 NIFTY 200
#   5 NIFTY 200 TR
#   6 NIFTY 50
#   7 NIFTY 50 FUTURES INDEX
#   8 NIFTY 50 FUTURES TR INDEX
#   9 NIFTY 50 TR
#  10 NIFTY 500
#  11 NIFTY 500 TR
#  12 NIFTY ADITYA BIRLA GROUP
#  13 NIFTY ADITYA BIRLA GROUP TR
#  14 NIFTY ALPHA 50
#  15 NIFTY ALPHA 50 TR
#  16 NIFTY ALPHA LOW-VOLATILITY 30
#  17 NIFTY ALPHA LOW-VOLATILITY 30 TR
#  18 NIFTY ALPHA QUALITY LOW-VOLATILITY 30
#  19 NIFTY ALPHA QUALITY LOW-VOLATILITY 30 TR
#  20 NIFTY ALPHA QUALITY VALUE LOW-VOLATILITY 30
#  21 NIFTY ALPHA QUALITY VALUE LOW-VOLATILITY 30 TR
#  22 NIFTY AUTO
#  23 NIFTY AUTO TR
#  24 NIFTY BANK
#  25 NIFTY BANK TR
#  26 NIFTY COMMODITIES
#  27 NIFTY COMMODITIES TR
#  28 NIFTY CONSUMPTION
#  29 NIFTY CPSE
#  30 NIFTY CPSE TR
#  31 NIFTY DIV OPPS 50
#  32 NIFTY DIVIDEND OPPORTUNITIES 50 TR
#  33 NIFTY ENERGY
#  34 NIFTY ENERGY TR
#  35 NIFTY FIN SERVICE
#  36 NIFTY FINANCIAL SERVICES TR
#  37 NIFTY FMCG
#  38 NIFTY FMCG TR
#  39 NIFTY GROWSECT 15
#  40 NIFTY GROWTH SECTORS 15 TR
#  41 NIFTY GS 10YR
#  42 NIFTY GS 10YR CLN
#  43 NIFTY GS 11 15YR
#  44 NIFTY GS 15YRPLUS
#  45 NIFTY GS 4 8YR
#  46 NIFTY GS 8 13YR
#  47 NIFTY GS COMPSITE
#  48 NIFTY HIGH BETA 50
#  49 NIFTY HIGH BETA 50 TR
#  50 NIFTY INDIA CONSUMPTION TR
#  51 NIFTY INFRA
#  52 NIFTY INFRASTRUCTURE TR
#  53 NIFTY IT
#  54 NIFTY IT TR
#  55 NIFTY LargeMidcap 250
#  56 NIFTY LARGEMIDCAP 250 TR
#  57 NIFTY LOW VOLATILITY 50
#  58 NIFTY LOW VOLATILITY 50 TR
#  59 NIFTY MAHINDRA GROUP
#  60 NIFTY MAHINDRA GROUP TR
#  61 NIFTY MEDIA
#  62 NIFTY MEDIA TR
#  63 NIFTY METAL
#  64 NIFTY METAL TR
#  65 NIFTY MID LIQ 15
#  66 NIFTY MIDCAP 100
#  67 NIFTY MIDCAP 100 TR
#  68 NIFTY MIDCAP 150
#  69 NIFTY MIDCAP 150 TR
#  70 NIFTY MIDCAP 50
#  71 NIFTY MIDCAP 50 TR
#  72 NIFTY MIDCAP LIQUID 15 TR
#  73 NIFTY MIDSMALLCAP 400
#  74 NIFTY MIDSMALLCAP 400 TR
#  75 NIFTY MNC
#  76 NIFTY MNC TR
#  77 NIFTY NEXT 50
#  78 NIFTY NEXT 50 TR
#  79 NIFTY PHARMA
#  80 NIFTY PHARMA TR
#  81 NIFTY PRIVATE BANK TR
#  82 NIFTY PSE
#  83 NIFTY PSE TR
#  84 NIFTY PSU BANK
#  85 NIFTY PSU BANK TR
#  86 NIFTY PVT BANK
#  87 NIFTY QUALITY LOW-VOLATILITY 30
#  88 NIFTY QUALITY LOW-VOLATILITY 30 TR
#  89 NIFTY REALTY
#  90 NIFTY REALTY TR
#  91 NIFTY SERV SECTOR
#  92 NIFTY SERVICES SECTOR TR
#  93 NIFTY SHARIAH 25
#  94 NIFTY SHARIAH 25 TR
#  95 NIFTY SMALLCAP 100 TR
#  96 NIFTY SMALLCAP 250
#  97 NIFTY SMALLCAP 250 TR
#  98 NIFTY SMALLCAP 50
#  99 NIFTY SMALLCAP 50 TR
# 100 NIFTY SME EMERGE
# 101 NIFTY SME EMERGE TR
# 102 NIFTY SMLCAP 100
# 103 NIFTY TATA GROUP
# 104 NIFTY TATA GROUP 25% CAP
# 105 NIFTY TATA GROUP 25% CAP TR
# 106 NIFTY TATA GROUP TR
# 107 NIFTY100 Enhanced ESG
# 108 NIFTY100 ENHANCED ESG TR
# 109 NIFTY100 EQL WGT
# 110 NIFTY100 EQUAL WEIGHT TR
# 111 NIFTY100 ESG
# 112 NIFTY100 ESG TR
# 113 NIFTY100 LIQ 15
# 114 NIFTY100 LIQUID 15 TR
# 115 NIFTY100 LOW VOLATILITY 30 TR
# 116 NIFTY100 LOWVOL30
# 117 NIFTY100 QUALITY 30 TR
# 118 NIFTY200 QUALITY 30
# 119 NIFTY200 QUALITY 30 TR
# 120 NIFTY50 DIV POINT
# 121 NIFTY50 EQL WGT
# 122 NIFTY50 EQUAL WEIGHT TR
# 123 NIFTY50 PR 1X INV
# 124 NIFTY50 PR 2X LEV
# 125 NIFTY50 SHARIAH
# 126 NIFTY50 SHARIAH TR
# 127 NIFTY50 TR 1X INV
# 128 NIFTY50 TR 2X LEV
# 129 NIFTY50 VALUE 20
# 130 NIFTY50 VALUE 20 TR
# 131 NIFTY500 SHARIAH
# 132 NIFTY500 SHARIAH TR
# 133 NIFTY500 VALUE 50
# 134 NIFTY500 VALUE 50 TR
