# %% [markdown]
# # Using NasdaqOmx Index data-set
#
# The python version of this sample can be found [here](https://github.com/shyams80/plutons/blob/master/docs-py/NasdaqOmx.ipynb)

# %%
library(DBI)
library(plutoDbR)
library(plutoR)
library(tidyverse)
options("scipen"=999)
source("/usr/share/pluto/config.R")

library(ggthemes)
library(quantmod)
library(PerformanceAnalytics)

source("/usr/share/pluto/goofy/misc.common.R")
source("/usr/share/pluto/goofy/plot.common.R")

options(repr.plot.width=16, repr.plot.height=8)

#initialize
nasdaqOmx <- NasdaqOmx()

# %%
# fetch all "India" TR NASDAQOMX indices

nasdaqOmx$Meta() %>%
    inner_join(nasdaqOmx$TimeSeries()) %>%
    group_by(ID, NAME) %>%
    filter(NAME %like% '% india %') %>%
    summarize(ST = min(TIME_STAMP), ET = max(TIME_STAMP)) %>%
    print(n = Inf)
# Out:
# # Source:   lazy query [?? x 4]
# # Database: NORWAY:StockVizUs2:R
# # Groups:   ID
#          ID NAME                                          ST         ET
#       <int> <chr>                                         <chr>      <chr>
#  1 13120874 NASDAQ India Basic Matls TR Index (NQIN1000T) 2001-03-30 2019-09-10
#  2 13120916 NASDAQ India Cnsmr Goods TR Index (NQIN3000T) 2001-03-30 2019-09-10
#  3 13120939 NASDAQ India Cnsmr Svcs TR Index (NQIN5000T)  2005-03-31 2019-09-10
#  4 13120986 NASDAQ India Financials TR Index (NQIN8000T)  2001-03-30 2019-09-10
#  5 13121029 NASDAQ India Health Care TR Index (NQIN4000T) 2001-03-30 2019-09-10
#  6 13121072 NASDAQ India Inds TR Index (NQIN2000T)        2001-03-30 2019-09-10
#  7 13121187 NASDAQ India Oil & Gas TR Index (NQIN0001T)   2004-09-30 2019-09-10
#  8 13121253 NASDAQ India Tech TR Index (NQIN9000T)        2001-03-30 2019-09-10
#  9 13121272 NASDAQ India TR Index (NQINT)                 2001-03-30 2019-09-10
# 10 13121274 NASDAQ India Telecom TR Index (NQIN6000T)     2006-03-31 2019-09-10
# 11 13121316 NASDAQ India Utilities TR Index (NQIN7000T)   2004-09-30 2019-09-10

# %% [markdown]
# ### plot total returns

# %%
nqId <- 13121272 #NASDAQ India TR Index (NQINT)
startDate <- as.Date('2010-01-01')
endDate <- as.Date('2019-06-30')

nqVals <- nasdaqOmx$TimeSeries() %>%
    filter(ID == nqId & TIME_STAMP >= startDate & TIME_STAMP <= endDate) %>%
    select(TIME_STAMP, CLOSE) %>%
    collect() 
    
nqRets <- dailyReturn(xts(nqVals$CLOSE, as.Date(nqVals$TIME_STAMP)))

Common.PlotCumReturns(nqRets, "NASDAQ India TR Index", "in USD")
# Out:
# # A tibble: 6 x 2
#   TIME_STAMP CLOSE
#   <chr>      <dbl>
# 1 2010-01-04 1009.
# 2 2010-01-05 1021.
# 3 2010-01-06 1033.
# 4 2010-01-07 1033.
# 5 2010-01-08 1030.
# 6 2010-01-11 1043.
# Plot with title “NASDAQ India TR Index”

# %% [markdown]
# This notebook was created using [pluto](http://pluto.studio). Learn more [here](https://github.com/shyams80/pluto)
